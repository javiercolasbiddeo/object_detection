# %%
from pylabel import importer

# %%
def coco_to_csv(path_json, path_photos):
    
    dataset = importer.ImportCoco(path_json,
                                  path_to_images= path_photos,
                                  name="BCCD_coco")
    
    return dataset.df.reset_index()

# %%
df = coco_to_csv('/home/jupyter/main_dataset/train/label1.json', '/home/jupyter/main_dataset/train/data')

# %%
categories = ["Ambulance", "Parking meter", "Traffic light", "Bicycle", "Bus", "Vehicle registration plate", "Traffic sign", "Stop sign", "Motorcycle", "Vehicle", "Taxi", "Car"]

# %%
df = df[df.cat_name.apply(lambda x: x in categories)]

# %%
df.shape
# Out:
# (10739, 26)

# %%
df.head()
# Out:
#    id                             img_folder          img_filename img_path  \
# 0   0  /home/jupyter/main_dataset/train/data  aa03074bf3d68bb1.jpg
# 1   1  /home/jupyter/main_dataset/train/data  aa03074bf3d68bb1.jpg
# 2   2  /home/jupyter/main_dataset/train/data  cfb416e69ea6c6fa.jpg
# 3   3  /home/jupyter/main_dataset/train/data  190edecc570168f5.jpg
# 4   4  /home/jupyter/main_dataset/train/data  91173b5d90e594b4.jpg
#
#    img_id  img_width  img_height img_depth ann_segmented  ann_bbox_xmin  ...  \
# 0  100001       1024         550                                  38.40  ...
# 1  100001       1024         550                                 225.28  ...
# 2  100002       1024         768                                  85.76  ...
# 3  100003       1024         768                                 470.40  ...
# 4  100004       1024        1024                                  32.00  ...
#
#    ann_segmentation  ann_iscrowd  ann_pose  ann_truncated  ann_difficult  \
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
#
#    cat_id   cat_name  cat_supercategory split annotated
# 0       6  Ambulance                                  1
# 1       6  Ambulance                                  1
# 2       6  Ambulance                                  1
# 3       6  Ambulance                                  1
# 4       6  Ambulance                                  1
#
# [5 rows x 26 columns]

# %%
df.to_csv('/home/jupyter/notebook-javi/object_detection/tensorflow/labels_dataset2.csv')
