# %%
import time

# %%
    --img 1280 \
    --batch 4 \
    --epochs 100 \
    --data /home/jupyter/motorcycle/YOLO_store.yaml \
    --weights yolov5x6.pt  \
    --project /home/jupyter \
    --name motorcycle \
    --patience 5 \
    --label-smoothing 0.1 \
    --seed 42

# %%
# Train YOLOv5s on COCO128 for 3 epochs
start_time = time.time()
# !python /home/jupyter/yolov5/train.py \
    --img 1280 \
    --batch 2 \
    --epochs 100 \
    --data /home/jupyter/11_categorias/YOLO_store.yaml \
    --project /home/jupyter/results\
    --name 11_categorias\
    --weights yolov5x6.pt  \
    --label-smoothing 0.1 \
    --patience 5 \
    --seed 42

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# train: weights=yolov5x6.pt, cfg=, data=/home/jupyter/11_categorias/YOLO_store.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=2, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/home/jupyter/results, name=11_categorias, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.1, patience=5, freeze=[0], save_period=-1, seed=42, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# error: cannot lock ref 'refs/remotes/origin/exp8': 'refs/remotes/origin/exp8/shortcut_gain' exists; cannot create 'refs/remotes/origin/exp8'
# From https://github.com/ultralytics/yolov5
#  ! [new branch]      exp8       -> origin/exp8  (unable to update local ref)
# Command 'git fetch origin' returned non-zero exit status 1.
# ...

# %%
#    --project /home/jupyter \
#    --name motorcycle \

# %%
# !python /home/jupyter/yolov5/detect.py \
    --weights /home/jupyter/results/11_categorias2/weights/best.pt\
    --img 1280\
    --line-thickness=1\
    --conf 0.05 \
    --source /home/jupyter/IMG_3451.png
# Out:
# detect: weights=['/home/jupyter/results/11_categorias2/weights/best.pt'], source=/home/jupyter/IMG_3451.png, data=yolov5/data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.05, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=1, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-143-g63368e7 Python-3.7.12 torch-1.12.1+cu102 CUDA:0 (Tesla T4, 14910MiB)
#
# Fusing layers...
# Model summary: 416 layers, 145738072 parameters, 0 gradients, 220.8 GFLOPs
# image 1/1 /home/jupyter/IMG_3451.png: 1280x640 (no detections), 138.9ms
# Speed: 0.9ms pre-process, 138.9ms inference, 0.4ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to yolov5/runs/detect/exp7
